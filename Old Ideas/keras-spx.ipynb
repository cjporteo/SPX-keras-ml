# %%
import pandas as pd
import numpy as np
from collections import deque
from sklearn.preprocessing import MinMaxScaler
import random
import time

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint

LOOK_AHEAD = 3
TRAIN_RATIO = 0.8
SEQUENCE_LENGTH = 20

EPOCHS = 50
BATCH_SIZE = 32

MODEL_NAME = f'LA-{LOOK_AHEAD}--SL-{SEQUENCE_LENGTH}--{int(time.time())}'

df_main = pd.read_csv('dataset.csv', index_col='Date', parse_dates=['Date'])
df_main
# Out:
#                     SPX       DIX           GEX   SPY Volume  USO Price  \
# Date
# 2011-05-02  1361.219971  0.378842  1.897313e+09  126278700.0  44.930000
# 2011-05-03  1356.619995  0.383411  1.859731e+09  138375000.0  44.080002
# 2011-05-04  1347.319946  0.392122  1.717764e+09  182678500.0  43.259998
# 2011-05-05  1335.099976  0.405457  1.361864e+09  226900000.0  39.320000
# 2011-05-06  1340.199951  0.418649  1.490329e+09  222787200.0  38.869999
# ...                 ...       ...           ...          ...        ...
# 2020-04-03  2488.650000  0.506475 -4.630797e+08  135561200.0   5.900000
# 2020-04-06  2663.680000  0.446698  1.555165e+09  188061200.0   5.480000
# 2020-04-07  2659.410000  0.482110  1.533925e+09  201427200.0   5.090000
# 2020-04-08  2749.980000  0.501114  3.331833e+09  153774500.0   5.370000
# 2020-04-09  2789.820000  0.488574  2.608413e+09  190282700.0   4.980000
#
#              GLD Price  TY 1 mo  TY 3 mo  TY 6 mo  TY 1 yr  ...  TY 3 yr  \
# Date                                                        ...
# 2011-05-02  150.410004     0.02     0.05     0.10     0.22  ...     1.01
# 2011-05-03  149.880005     0.02     0.03     0.09     0.20  ...     1.01
# 2011-05-04  147.729996     0.02     0.03     0.07     0.19  ...     1.00
# 2011-05-05  143.470001     0.01     0.02     0.07     0.20  ...     0.97
# 2011-05-06  145.300003     0.02     0.02     0.07     0.18  ...     0.96
# ...                ...      ...      ...      ...      ...  ...      ...
# 2020-04-03  152.649994     0.09     0.10     0.15     0.15  ...     0.30
# 2020-04-06  156.880005     0.09     0.15     0.17     0.20  ...     0.35
# 2020-04-07  156.039993     0.10     0.14     0.20     0.20  ...     0.36
# 2020-04-08  154.649994     0.14     0.22     0.24     0.23  ...     0.34
# 2020-04-09  158.690002     0.20     0.25     0.24     0.25  ...     0.29
#
#             TY 5 yr  TY 7 yr  TY 10 yr  TY 20 yr  TY 30 yr  VIX P/C Ratio  \
# Date
# 2011-05-02     1.96     2.66      3.31      4.14      4.38           0.51
# 2011-05-03     1.96     2.64      3.28      4.11      4.36           0.39
# 2011-05-04     1.95     2.61      3.25      4.08      4.33           0.87
# 2011-05-05     1.88     2.54      3.18      4.00      4.26           1.36
# 2011-05-06     1.87     2.54      3.19      4.03      4.29           0.41
# ...             ...      ...       ...       ...       ...            ...
# 2020-04-03     0.39     0.52      0.62      1.05      1.24           0.66
# 2020-04-06     0.44     0.58      0.67      1.08      1.27           1.14
# 2020-04-07     0.48     0.64      0.75      1.13      1.32           1.67
# 2020-04-08     0.47     0.65      0.77      1.18      1.37           1.11
# 2020-04-09     0.41     0.60      0.73      1.15      1.35           0.81
#
#             VIX Options Volume  SPX P/C Ratio  SPX Options Volume
# Date
# 2011-05-02            182366.0           1.38            567584.0
# 2011-05-03            318780.0           1.84            540934.0
# 2011-05-04            369293.0           2.08            432621.0
# 2011-05-05            446203.0           1.94            601038.0
# 2011-05-06            382407.0           1.85            601669.0
# ...                        ...            ...                 ...
# 2020-04-03            351100.0           1.72           1362044.0
# 2020-04-06            536473.0           1.27           1421641.0
# 2020-04-07            380770.0           1.12           1315103.0
# 2020-04-08            325232.0           1.39           1262348.0
# 2020-04-09            439073.0           1.27           1418972.0
#
# [2250 rows x 21 columns]

# %%
n = len(df_main)
n
# Out:
# 2250

# %%
#df_main['SPX Future Price'] = df_main['SPX'].shift(periods=-LOOK_AHEAD)
#df_main.dropna(inplace=True)

# %%
'''def label(curr_price, future_price):
    return 1 if future_price > curr_price else 0

df_main['Signal'] = list(map(label, df_main['SPX'], df_main['SPX Future Price']))
df_main = df_main.drop('SPX Future Price', axis=1)'''

df_main['DIX Diff.'] = df_main['DIX'].diff()
df_main['GEX Diff.'] = df_main['GEX'].diff()


def label(df, k, u=0.85, d=0.6):
    size = len(df)
    prices = df['SPX']
    labels = []
    
    for i in range(size):
        base_price = prices.iloc[i]
        label = 1 # hold
        for j in range(i+1, min(i+k+1, n)):
            new_price = prices.iloc[j]
            pct_change = 100 * (new_price-base_price)/base_price
            if pct_change >= u:
                label = 2 # buy
                break
            elif pct_change <= -d:
                label = 0 # sell
                break
        labels.append(label)
    
    df['Signal'] = labels

label(df_main, k=LOOK_AHEAD)
print(df_main['Signal'].value_counts())
df_main.tail(30)
# Out:
# 1    752
# 2    752
# 0    746
# Name: Signal, dtype: int64
#                 SPX       DIX           GEX   SPY Volume  USO Price  \
# Date
# 2020-02-28  2954.21  0.380413 -1.423445e+09  385764000.0       9.45
# 2020-03-02  3090.26  0.448496 -1.320902e+08  238703600.0       9.92
# 2020-03-03  3003.37  0.456905 -1.094765e+09  300139100.0       9.89
# 2020-03-04  3130.12  0.420300  1.292494e+09  176613400.0       9.86
# 2020-03-05  3024.08  0.442533 -9.922481e+08  186366800.0       9.61
# 2020-03-06  2972.40  0.452162 -1.026985e+09  228667200.0       8.73
# 2020-03-09  2746.52  0.416465 -1.664364e+09  309417300.0       6.52
# 2020-03-10  2882.24  0.418250 -1.000251e+09  276444100.0       7.24
# 2020-03-11  2741.38  0.439415 -1.628877e+09  255316300.0       6.94
# 2020-03-12  2480.64  0.377596 -2.170934e+09  392220700.0       6.54
# 2020-03-13  2710.94  0.390936 -1.540240e+09  329566100.0       6.96
# 2020-03-16  2386.13  0.372537 -1.758235e+09  297240000.0       6.05
# 2020-03-17  2529.09  0.352458 -1.153920e+09  262070500.0       5.71
# 2020-03-18  2398.42  0.354209 -2.314059e+08  327597100.0       4.71
# 2020-03-19  2409.53  0.353335 -1.009988e+09  289322000.0       5.37
# 2020-03-20  2304.88  0.411404 -6.417786e+08  347158800.0       4.94
# 2020-03-23  2237.40  0.366571 -6.780356e+07  326025200.0       4.88
# 2020-03-23           1.36           1593954.0  -0.044833  5.739750e+08       2
# 2020-03-24           1.16           1522470.0   0.035637  6.680235e+08       2
# 2020-03-25           1.11           1740055.0   0.058977 -7.578666e+08       2
# 2020-03-26           1.44           1393379.0   0.019756  1.264376e+09       0
# 2020-03-27           1.43           1428892.0   0.001885 -1.396115e+09       2
# 2020-03-30           1.38           1310523.0  -0.010086  3.880057e+08       0
# 2020-03-31           1.38           1557509.0   0.024677 -2.468311e+08       0
# 2020-04-01           1.63           1399752.0   0.013985 -6.246392e+08       2
# 2020-04-02           1.57           1123403.0  -0.026180  2.654516e+08       0
# 2020-04-03           1.72           1362044.0   0.021254  4.431874e+07       2
# 2020-04-06           1.27           1421641.0  -0.059777  2.018244e+09       2
# 2020-04-07           1.12           1315103.0   0.035412 -2.123946e+07       2
# 2020-04-08           1.39           1262348.0   0.019004  1.797908e+09       2
# 2020-04-09           1.27           1418972.0  -0.012540 -7.234200e+08       1
#
# [30 rows x 24 columns]

# %%
df_main = df_main[:-LOOK_AHEAD]

# %%
def make_stationary(df):
    
    ln_ratio_cols = [
        'SPX',
        'SPY Volume',
        'USO Price',
        'GLD Price',
        #'VIX P/C Ratio',
        'VIX Options Volume',
        #'SPX P/C Ratio',
        'SPX Options Volume'
    ]
    
    diff_cols = [
        #'DIX',
        #'GEX'
    ]
    
    alt_features = [
        'SPX',
        'DIX',
        'GEX',
        'DIX Diff.',
        'GEX Diff.',
        'VIX P/C Ratio',
        'SPX P/C Ratio',
        'Signal'
    ]
    
    TY_cols = [col for col in df.columns if 'TY' in col]
    #diff_cols.extend(TY_cols)
    
    for col in ln_ratio_cols:
        if col in df.columns:
            df[col] = np.log1p(df[col].pct_change())
    
    for col in diff_cols:
        if col in df.columns:
            df[col] = df[col].diff()
    
    #df['GEX'] = list(map(lambda x : x/1000, df['GEX']))
    
    
    df = df[alt_features]
    
    return df

df_old = df_main.copy()
df_main = make_stationary(df_main)
df_main
# Out:
# <ipython-input-377-71a2678187b1>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = np.log1p(df[col].pct_change())
#                  SPX       DIX           GEX  DIX Diff.     GEX Diff.  \
# Date
# 2011-05-02       NaN  0.378842  1.897313e+09        NaN           NaN
# 2011-05-03 -0.003385  0.383411  1.859731e+09   0.004569 -3.758192e+07
# 2011-05-04 -0.006879  0.392122  1.717764e+09   0.008711 -1.419668e+08
# 2011-05-05 -0.009111  0.405457  1.361864e+09   0.013335 -3.558996e+08
# 2011-05-06  0.003813  0.418649  1.490329e+09   0.013192  1.284643e+08
# ...              ...       ...           ...        ...           ...
# 2020-03-31 -0.016142  0.497417 -1.482108e+08   0.024677 -2.468311e+08
# 2020-04-01 -0.045146  0.511401 -7.728500e+08   0.013985 -6.246392e+08
# 2020-04-02  0.022573  0.485221 -5.073984e+08  -0.026180  2.654516e+08
# 2020-04-03 -0.015253  0.506475 -4.630797e+08   0.021254  4.431874e+07
# 2020-04-06  0.067968  0.446698  1.555165e+09  -0.059777  2.018244e+09
#
#             VIX P/C Ratio  SPX P/C Ratio  Signal
# Date
# 2011-05-02           0.51           1.38       0
# 2011-05-03           0.39           1.84       0
# 2011-05-04           0.87           2.08       0
# 2011-05-05           1.36           1.94       2
# 2011-05-06           0.41           1.85       2
# ...                   ...            ...     ...
# 2020-03-31           1.30           1.38       0
# 2020-04-01           1.14           1.63       2
# 2020-04-02           1.62           1.57       0
# 2020-04-03           0.66           1.72       2
# 2020-04-06           1.14           1.27       2
#
# [2247 rows x 8 columns]

# %%
train_index = int(n*TRAIN_RATIO)

df_train = df_main.iloc[ :train_index, : ].dropna()
df_test = df_main.iloc[train_index: , : ].dropna()

y_train = df_train['Signal']
y_test = df_test['Signal']

scaler = MinMaxScaler()
scaler.fit(df_train)
train = scaler.transform(df_train)
test = scaler.transform(df_test)

train[:,-1] = y_train
test[:,-1] = y_test

#print(train)
#print(test)

def preprocess_data(array):
    
    '''
    for col in df.columns:
        if col != 'Signal':
            col = scale(df[col].values)
    '''
    
    sequences = []
    prev_days = deque(maxlen=SEQUENCE_LENGTH)
    
    for row in array:
        
        prev_days.append([value for value in row[:-1]])
        if len(prev_days) == SEQUENCE_LENGTH:
            
            #sequence = scale(np.array(prev_days))
            sequence = np.array(prev_days)
            sequences.append([sequence, row[-1]])
    
    random.shuffle(sequences)
    
    buys, holds, sells = [], [], []
    
    for seq, signal in sequences:
        if signal == 2:
            buys.append([seq, signal])
        elif signal == 1:
            holds.append([seq, signal])
        else:
            sells.append([seq, signal])
            
    smallest = min(len(buys), len(holds), len(sells))
    buys = buys[:smallest]
    holds = holds[:smallest]
    sells = sells[:smallest]
    
    sequences = buys+holds+sells
    
    random.shuffle(sequences)
    
    X, y = [], []
    
    for seq, signal in sequences:
        X.append(seq)
        y.append(signal)
    
    return np.array(X), np.array(y)

X_train, y_train = preprocess_data(train)
X_test, y_test = preprocess_data(test)

y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
print(X_train[0])
print(y_train[0])
# Out:
# [[0.60760618 0.3004223  0.33233751 0.4968006  0.56885542 0.06291391
#   0.14189189]
#  [0.61394679 0.31932456 0.34738626 0.50557932 0.58692579 0.17549669
#   0.20608108]
#  [0.63698965 0.3647588  0.35584291 0.53721645 0.58050899 0.17880795
#   0.18243243]
#  [0.62634293 0.31179867 0.37309154 0.41988947 0.58906718 0.22847682
#   0.20608108]
#  [0.57733035 0.39482122 0.35586589 0.58203736 0.5555096  0.16556291
#   0.19256757]
#  [0.60959501 0.34800624 0.35637684 0.42721703 0.57277457 0.08278146
#   0.11486486]
#  [0.64667271 0.30382493 0.38870984 0.43035746 0.60375044 0.10927152
#   0.09459459]
#  [0.58415201 0.43566767 0.42089945 0.64025133 0.60361087 0.11589404
#   0.375     ]
#  [0.55026982 0.58004733 0.30948787 0.65520054 0.46382814 0.15562914
#   0.28040541]
#  [0.57716271 0.47640222 0.29844717 0.35945189 0.56153009 0.12582781
#   0.39189189]
#  [0.65610932 0.31670544 0.31883806 0.292615   0.59212588 0.05629139
#   0.34459459]
#  [0.52605526 0.50870675 0.29073811 0.71198535 0.54492445 0.06622517
#   0.27702703]
#  [0.66021669 0.40158603 0.31445221 0.35530752 0.59536073 0.11258278
#   0.38851351]
#  [0.56918047 0.45903708 0.31153505 0.55154549 0.56943762 0.06622517
#   0.50337838]
#  [0.66547642 0.43402887 0.33546651 0.45321977 0.5955723  0.07615894
#   0.24662162]
#  [0.59309795 0.46687935 0.31416079 0.52221139 0.55153802 0.0794702
#   0.14527027]
#  [0.63332309 0.34971655 0.32074095 0.34333318 0.5786824  0.05960265
#   0.23310811]
#  [0.55930861 0.37833983 0.29440802 0.51717082 0.54664449 0.0794702
#   0.15540541]
#  [0.64295626 0.25610891 0.311533   0.33728987 0.58894682 0.09602649
#   0.16216216]
#  [0.50623141 0.4332532  0.27167976 0.6942696  0.53348369 0.16225166
#   0.19256757]]
# [0. 1. 0.]

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 1740
# 387

# %%
model = Sequential()

model.add(LSTM(256, input_shape=(X_train.shape[1:]), return_sequences=True, activation='tanh'))
model.add(Dropout(0.1))
model.add(BatchNormalization())

model.add(LSTM(128, return_sequences=True, activation='tanh'))
model.add(Dropout(0.1))
model.add(BatchNormalization())

model.add(LSTM(64, activation='tanh'))
model.add(Dropout(0.1))
model.add(BatchNormalization())

'''
model.add(LSTM(128, return_sequences=True, activation='tanh'))
#model.add(Dropout(0.1))
model.add(BatchNormalization())

model.add(LSTM(128, activation='tanh'))
#model.add(Dropout(0.1))
model.add(BatchNormalization())
'''

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(3, activation='softmax'))

opt = tf.keras.optimizers.Adam(lr=0.0005, decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

tensorboard = TensorBoard(log_dir=f'logs/{MODEL_NAME}')

#filepath = "RNN_Final-{epoch:02d}-{val_acc:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
#checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor="val_acc", verbose=1, save_best_only=True, mode='max')) # saves only the best ones

history = model.fit(X_train,
                    y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(X_test, y_test),
                    callbacks=[tensorboard])

model.save(f'{MODEL_NAME}.model')
# Out:
# Epoch 1/50
#  2/55 [>.............................] - ETA: 1:42 - loss: 1.6414 - accuracy: 0.2969WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (1.890618). Check your callbacks.
# 55/55 [==============================] - 10s 179ms/step - loss: 1.2781 - accuracy: 0.3753 - val_loss: 1.0912 - val_accuracy: 0.4574
# Epoch 2/50
# 55/55 [==============================] - 5s 94ms/step - loss: 1.1689 - accuracy: 0.3874 - val_loss: 1.0969 - val_accuracy: 0.3127
# Epoch 3/50
# 55/55 [==============================] - 6s 102ms/step - loss: 1.1278 - accuracy: 0.4063 - val_loss: 1.0961 - val_accuracy: 0.2972
# Epoch 4/50
# 55/55 [==============================] - 5s 96ms/step - loss: 1.1026 - accuracy: 0.4230 - val_loss: 1.0466 - val_accuracy: 0.4599
# Epoch 5/50
# 55/55 [==============================] - 5s 100ms/step - loss: 1.0732 - accuracy: 0.4224 - val_loss: 1.0667 - val_accuracy: 0.4341
# Epoch 6/50
# 55/55 [==============================] - 5s 94ms/step - loss: 1.0719 - accuracy: 0.4333 - val_loss: 1.0663 - val_accuracy: 0.3928
# Epoch 7/50
# 55/55 [==============================] - 5s 97ms/step - loss: 1.0549 - accuracy: 0.4575 - val_loss: 1.0782 - val_accuracy: 0.4729
# Epoch 8/50
# 55/55 [==============================] - 5s 92ms/step - loss: 1.0381 - accuracy: 0.4563 - val_loss: 1.0477 - val_accuracy: 0.4134
# Epoch 9/50
# 55/55 [==============================] - 5s 94ms/step - loss: 1.0530 - accuracy: 0.4431 - val_loss: 1.0514 - val_accuracy: 0.4832
# Epoch 10/50
# 55/55 [==============================] - 5s 100ms/step - loss: 1.0064 - accuracy: 0.4885 - val_loss: 1.0518 - val_accuracy: 0.4005
# Epoch 11/50
# 55/55 [==============================] - 5s 100ms/step - loss: 1.0150 - accuracy: 0.4776 - val_loss: 1.1834 - val_accuracy: 0.3566
# Epoch 12/50
# 55/55 [==============================] - 5s 98ms/step - loss: 1.0077 - accuracy: 0.4713 - val_loss: 1.2086 - val_accuracy: 0.4134
# Epoch 13/50
# 55/55 [==============================] - 6s 104ms/step - loss: 1.0042 - accuracy: 0.4793 - val_loss: 1.0722 - val_accuracy: 0.4574
# Epoch 14/50
# 55/55 [==============================] - 6s 110ms/step - loss: 0.9809 - accuracy: 0.5017 - val_loss: 1.0750 - val_accuracy: 0.4109
# Epoch 15/50
# 55/55 [==============================] - 5s 98ms/step - loss: 0.9843 - accuracy: 0.5017 - val_loss: 1.2123 - val_accuracy: 0.3953
# Epoch 16/50
# 55/55 [==============================] - 6s 106ms/step - loss: 0.9794 - accuracy: 0.5115 - val_loss: 1.1867 - val_accuracy: 0.4341
# Epoch 17/50
# 55/55 [==============================] - 6s 104ms/step - loss: 0.9715 - accuracy: 0.4971 - val_loss: 1.3895 - val_accuracy: 0.3798
# Epoch 18/50
# 55/55 [==============================] - 6s 102ms/step - loss: 0.9745 - accuracy: 0.5063 - val_loss: 1.1732 - val_accuracy: 0.4212
# Epoch 19/50
# 55/55 [==============================] - 6s 102ms/step - loss: 0.9643 - accuracy: 0.5075 - val_loss: 1.1726 - val_accuracy: 0.4729
# Epoch 20/50
# 55/55 [==============================] - 6s 106ms/step - loss: 0.9506 - accuracy: 0.5270 - val_loss: 1.1586 - val_accuracy: 0.3953
# Epoch 21/50
# 55/55 [==============================] - 6s 104ms/step - loss: 0.9435 - accuracy: 0.5299 - val_loss: 1.4296 - val_accuracy: 0.3695
# Epoch 22/50
# 55/55 [==============================] - 5s 100ms/step - loss: 0.9497 - accuracy: 0.5236 - val_loss: 1.1108 - val_accuracy: 0.4134
# Epoch 23/50
# 55/55 [==============================] - 6s 116ms/step - loss: 0.9180 - accuracy: 0.5517 - val_loss: 1.0633 - val_accuracy: 0.4264
# Epoch 24/50
# 55/55 [==============================] - 6s 100ms/step - loss: 0.9357 - accuracy: 0.5328 - val_loss: 1.2237 - val_accuracy: 0.4315
# Epoch 25/50
# 55/55 [==============================] - 6s 116ms/step - loss: 0.9307 - accuracy: 0.5264 - val_loss: 1.4067 - val_accuracy: 0.3488
# Epoch 26/50
# 55/55 [==============================] - 6s 115ms/step - loss: 0.9121 - accuracy: 0.5414 - val_loss: 1.0682 - val_accuracy: 0.4651
# Epoch 27/50
# 55/55 [==============================] - 6s 104ms/step - loss: 0.9060 - accuracy: 0.5603 - val_loss: 1.1860 - val_accuracy: 0.4419
# Epoch 28/50
# 55/55 [==============================] - 6s 109ms/step - loss: 0.9055 - accuracy: 0.5621 - val_loss: 1.1528 - val_accuracy: 0.4419
# Epoch 29/50
# 55/55 [==============================] - 6s 109ms/step - loss: 0.9109 - accuracy: 0.5684 - val_loss: 1.3436 - val_accuracy: 0.4160
# Epoch 30/50
# 55/55 [==============================] - 6s 102ms/step - loss: 0.8975 - accuracy: 0.5747 - val_loss: 1.1974 - val_accuracy: 0.3876
# Epoch 31/50
# 55/55 [==============================] - 6s 112ms/step - loss: 0.8639 - accuracy: 0.5954 - val_loss: 1.2484 - val_accuracy: 0.4651
# Epoch 32/50
# 55/55 [==============================] - 6s 105ms/step - loss: 0.8873 - accuracy: 0.5776 - val_loss: 1.1823 - val_accuracy: 0.4729
# Epoch 33/50
# 55/55 [==============================] - 6s 102ms/step - loss: 0.8440 - accuracy: 0.6017 - val_loss: 1.3440 - val_accuracy: 0.3876
# Epoch 34/50
# 55/55 [==============================] - 6s 103ms/step - loss: 0.8549 - accuracy: 0.6075 - val_loss: 1.4969 - val_accuracy: 0.3643
# Epoch 35/50
# 55/55 [==============================] - 6s 104ms/step - loss: 0.8488 - accuracy: 0.6023 - val_loss: 1.3044 - val_accuracy: 0.3747
# Epoch 36/50
# 55/55 [==============================] - 6s 112ms/step - loss: 0.8589 - accuracy: 0.6006 - val_loss: 1.1572 - val_accuracy: 0.4393
# Epoch 37/50
# 55/55 [==============================] - 6s 103ms/step - loss: 0.8232 - accuracy: 0.6230 - val_loss: 1.2604 - val_accuracy: 0.4289
# Epoch 38/50
# 55/55 [==============================] - 6s 114ms/step - loss: 0.8087 - accuracy: 0.6109 - val_loss: 1.2305 - val_accuracy: 0.4677
# Epoch 39/50
# 55/55 [==============================] - 7s 118ms/step - loss: 0.8127 - accuracy: 0.6293 - val_loss: 1.2197 - val_accuracy: 0.4186
# Epoch 40/50
# 55/55 [==============================] - 6s 109ms/step - loss: 0.7906 - accuracy: 0.6414 - val_loss: 1.3811 - val_accuracy: 0.3643
# Epoch 41/50
# 55/55 [==============================] - 7s 122ms/step - loss: 0.7827 - accuracy: 0.6408 - val_loss: 1.3157 - val_accuracy: 0.4160
# Epoch 42/50
# 55/55 [==============================] - 6s 112ms/step - loss: 0.7887 - accuracy: 0.6454 - val_loss: 1.2742 - val_accuracy: 0.3876
# Epoch 43/50
# 55/55 [==============================] - 6s 111ms/step - loss: 0.7714 - accuracy: 0.6540 - val_loss: 1.4449 - val_accuracy: 0.4031
# Epoch 44/50
# 55/55 [==============================] - 6s 116ms/step - loss: 0.7641 - accuracy: 0.6540 - val_loss: 1.4296 - val_accuracy: 0.4651
# Epoch 45/50
# 55/55 [==============================] - 7s 120ms/step - loss: 0.7365 - accuracy: 0.6626 - val_loss: 1.4911 - val_accuracy: 0.4238
# Epoch 46/50
# 55/55 [==============================] - 6s 107ms/step - loss: 0.7443 - accuracy: 0.6793 - val_loss: 1.4139 - val_accuracy: 0.4005
# Epoch 47/50
# 55/55 [==============================] - 6s 115ms/step - loss: 0.7118 - accuracy: 0.6879 - val_loss: 1.5541 - val_accuracy: 0.3953
# Epoch 48/50
# 33/55 [=================>............] - ETA: 2s - loss: 0.6949 - accuracy: 0.7093

# %%
model.summary()
